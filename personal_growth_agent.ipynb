# %%
from agno.agent import Agent
from agno.models.google import Gemini
from agno.team.team import Team
from dotenv import load_dotenv

load_dotenv()

# Define personal growth agents

goal_agent = Agent(
    name="Goal Setting Agent",
    role="Help users set, plan, and achieve personal and professional goals.",
    model=Gemini(id="gemini-2.0-flash"),
    instructions=[
        "You're a goal coach. Guide users in setting SMART goals, breaking them into steps, and tracking progress.",
    ],
)

time_agent = Agent(
    name="Time Management Agent",
    role="Advise on prioritization, schedules, and overcoming procrastination.",
    model=Gemini(id="gemini-2.0-flash"),
    instructions=[
        "You're a time management expert. Teach effective routines, deep work, calendar use, and time blocking.",
    ],
)

mindfulness_agent = Agent(
    name="Mindfulness Agent",
    role="Promote emotional balance and mindfulness through simple practices.",
    model=Gemini(id="gemini-2.0-flash"),
    instructions=[
        "You're a mindfulness coach. Share meditation tips, breathing techniques, and mindset training.",
    ],
)

habits_agent = Agent(
    name="Habits Coach Agent",
    role="Help users build and stick to good habits and break bad ones.",
    model=Gemini(id="gemini-2.0-flash"),
    instructions=[
        "You're a habit formation expert. Guide users in building small consistent habits using methods like habit stacking and cues.",
    ],
)

fallback_agent = Agent(
    name="Fallback Agent",
    role="Respond politely when the question is unrelated to personal development.",
    model=Gemini(id="gemini-2.0-flash"),
    instructions=[
        "If the topic isn't related to personal growth, respond politely saying it's outside your scope.",
    ],
)

# Team
growth_team = Team(
    name="Personal Growth & Development Team",
    mode="route",
    model=Gemini(id="gemini-2.0-flash"),
    members=[goal_agent, time_agent, mindfulness_agent, habits_agent, fallback_agent],
    instructions=[
        "Route goal-setting questions to the Goal Setting Agent.",
        "Route questions about managing time or productivity to the Time Management Agent.",
        "Route questions about stress, emotions, or mindfulness to the Mindfulness Agent.",
        "Route questions about building or breaking habits to the Habits Coach Agent.",
        "Use the Fallback Agent for unrelated topics.",
    ],
    markdown=True,
    show_members_responses=True,
)

# Example function
def ask_question(question: str):
    response = growth_team.run(question)
    print(f"Question: {question}")
    print(f"Answer:\n{response.content}")
    print("-" * 50)

# Example prompts
ask_question("How do I set achievable goals for the next 6 months?")
ask_question("I struggle with procrastination. Any tips?")
ask_question("What’s a good morning mindfulness routine?")
ask_question("How do I break the habit of late-night phone usage?")
ask_question("Who won the last cricket world cup?")
# Out:
# Question: How do I set achievable goals for the next 6 months?
# Answer:
# Okay, let's set you up for success over the next 6 months! Here’s a step-by-step guide to setting achievable goals, using the SMART framework:
#
# **1. Brainstorm & Identify Areas of Focus:**
#
# *   **What do you want to achieve?** Think broadly at first. What areas of your life or work do you want to improve? Consider:
#     *   **Career:** Promotion, new skills, job change?
#     *   **Personal Development:** Learning a language, a new hobby, improving a skill?
#     *   **Health & Fitness:** Weight loss, running a marathon, healthier eating?
#     *   **Financial:** Saving, investing, paying off debt?
#     *   **Relationships:** Strengthening bonds, meeting new people?
# *   **Write everything down.** Don't censor yourself at this stage. Just get all your ideas out.
#
# **2. Prioritize & Choose a Few Key Goals:**
#
# *   **Realistically, how much can you handle?** It's better to achieve a few goals well than to fail at many. I recommend focusing on no more than 2-3 major goals for the next 6 months.
# *   **Consider impact:** Which goals will have the biggest positive impact on your life?
# *   **Which goals align with your values and long-term vision?**
#
# **3. Make Your Goals SMART:**
#
# For *each* goal you've chosen, refine it using the SMART criteria:
#
# *   **S - Specific:**
#     *   What *exactly* do you want to achieve? Be as clear as possible.
#     *   Instead of "Get in shape," try "Lose 10 pounds."
# *   **M - Measurable:**
#     *   How will you track your progress? What metrics will you use?
#     *   Can you quantify your goal?
#     *   Examples: "Save $100 per month," "Read one book per month," "Run 3 times a week."
# *   **A - Achievable:**
#     *   Is this goal realistic given your current circumstances, resources, and time?
#     *   Be honest with yourself. It's better to set a slightly easier goal and exceed it than to set an impossible goal and get discouraged.
#     *   Consider breaking down a large goal into smaller, more manageable sub-goals (we'll get to this in the next step).
# *   **R - Relevant:**
#     *   Does this goal align with your overall values, needs, and long-term aspirations?
#     *   Is it worth your time and effort?
#     *   Why is this goal important to you *right now*?
# *   **T - Time-Bound:**
#     *   When do you want to achieve this goal by? Set a clear deadline (6 months from now, in this case).
#     *   Having a deadline creates urgency and helps you stay on track.
#     *   You can also set smaller deadlines for sub-goals.
#
# **Example:**
#
# *   **Original Goal:** "Learn to code."
# *   **SMART Goal:** "Complete an online Python course (specific) on Codecademy (measurable by course progress) and build a basic personal website (measurable by having a functional website) within 6 months (time-bound). This will help me develop valuable skills for a career change (relevant) and is achievable by dedicating 5 hours per week to learning (achievable)."
#
# **4. Break Down Goals into Smaller Steps:**
#
# *   **Identify Milestones:** What are the key milestones you need to reach to achieve your goal?
# *   **Create Actionable Tasks:** What specific actions do you need to take each week or month to reach those milestones?
# *   **Example (Continuing the Python Example):**
#     *   **Month 1:** Complete the first module of the Codecademy course. (Action: Dedicate 5 hours per week to Codecademy).
#     *   **Month 2:** Complete the second module and start researching website hosting options. (Action: Dedicate 5 hours per week to Codecademy, spend 1 hour researching hosting).
#     *   **Month 3:** Complete the Codecademy course. (Action: Dedicate 5 hours per week to Codecademy)
#     *   **Month 4:** Design the basic structure of your website. (Action: Dedicate 5 hours to website design)
#     *   **Month 5:** Start coding the website. (Action: Dedicate 5 hours to coding)
#     *   **Month 6:** Finish coding the website and deploy it online. (Action: Dedicate 5 hours to coding and deploying.)
#
# **5. Plan & Schedule:**
#
# *   **Allocate Time:** Schedule specific times in your week to work on your goals. Treat these appointments with yourself as seriously as you would any other important meeting.
# *   **Use a Calendar or Planner:** Write down your tasks and deadlines.
# *   **Set Reminders:** Use your phone or calendar to remind you of upcoming tasks.
#
# **6. Track Your Progress & Stay Accountable:**
#
# *   **Regularly Review:** At least once a week, review your progress. Are you on track? If not, why not?
# *   **Adjust as Needed:** Don't be afraid to adjust your goals or your plan if things aren't working. Life happens! The key is to stay flexible and keep moving forward.
# *   **Celebrate Small Wins:** Acknowledge and celebrate your achievements along the way. This will help you stay motivated.
# *   **Find an Accountability Partner:** Share your goals with a friend, family member, or mentor and ask them to check in on your progress.
#
# **7. Stay Motivated:**
#
# *   **Visualize Success:** Imagine yourself achieving your goals. How will it feel?
# *   **Remind Yourself of Your "Why":** Keep your reasons for pursuing these goals top of mind.
# *   **Reward Yourself:** Plan small rewards for achieving milestones.
#
# **To help me tailor this advice further, tell me:**
#
# *   What are some areas you're considering focusing on? (Career, health, finances, etc.)
# *   What are some initial ideas you have for goals?
#
# Once I have that information, I can help you refine your goals and create a more specific plan! Good luck!
#
# --------------------------------------------------
# Question: I struggle with procrastination. Any tips?
# Answer:
# Okay, let's break down how to set achievable goals for the next 6 months. We'll focus on making them realistic, manageable, and motivating.
#
# **1. The Foundation: Self-Reflection and Big Picture Thinking**
#
# *   **What truly matters?** Before diving into specifics, take some time for introspection.  What areas of your life do you want to improve? What makes you excited? What feels neglected? Think career, health, relationships, personal growth, finances, etc.
# *   **Vision Board (Optional):** Creating a visual representation of your aspirations can be incredibly motivating. This could be a physical collage or a digital board.  The point is to solidify your long-term vision.
# *   **The "Why":** For each area, ask yourself *why* you want to improve it.  For example, "I want to exercise more *because* I want to feel more energetic and confident."  The stronger your "why," the easier it will be to stay committed.
#
# **2. Goal Setting: The SMART Framework is Your Friend**
#
# The SMART framework ensures your goals are well-defined and attainable.
#
# *   **Specific:**  Instead of "Get in better shape," try "Run a 5k in under 30 minutes."  The more specific, the better.
# *   **Measurable:** How will you track progress?  "Write 500 words per day," is measurable.  "Write more" is not.
# *   **Achievable:** Be realistic. Don't aim for something impossible in 6 months. Consider your current abilities, resources, and time constraints.  Better to underestimate and exceed expectations than to fail trying to do too much.
# *   **Relevant:**  Does this goal align with your overall values and long-term vision?  Is it something you genuinely *want* to achieve?  If a goal doesn't feel relevant, it's less likely to stick.
# *   **Time-bound:** Set a deadline.  "Run a 5k in under 30 minutes *by December 31st*."  This creates a sense of urgency and helps you stay on track.
#
# **Example:**
#
# *   **Not SMART:** "Learn to code."
# *   **SMART:** "Complete an online Python programming course and build a basic web application by the end of December."
#
# **3. Breaking it Down: From 6 Months to Daily Actions**
#
# *   **Quarterly Goals:** Divide your 6-month goals into smaller, 3-month (quarterly) milestones. This makes the larger goals less daunting.
# *   **Monthly Goals:** Further break down each quarterly goal into monthly objectives.
# *   **Weekly Goals:** Define what you need to accomplish each week to stay on track with your monthly goals.
# *   **Daily Tasks:**  Identify the specific tasks you need to do each day to support your weekly goals. This is where the rubber meets the road.
#
# **Example (Continuing the Python Example):**
#
# *   **6-Month Goal:** Complete an online Python programming course and build a basic web application by the end of December.
# *   **Quarterly Goals:**
#     *   Q3 (July-Sept): Complete the first half of the Python course.
#     *   Q4 (Oct-Dec): Complete the second half of the course and begin building the web application.
# *   **Monthly Goals (October Example):**
#     *   Complete modules 7-10 of the Python course.
#     *   Research web application frameworks.
# *   **Weekly Goals (Week 1 of October Example):**
#     *   Complete module 7 of the Python course.
#     *   Read articles on Flask and Django.
# *   **Daily Tasks (Monday of Week 1 Example):**
#     *   Watch the first 2 videos of module 7.
#     *   Take notes on the videos.
#
# **4. Prioritization and Time Management**
#
# *   **The Eisenhower Matrix (Urgent/Important):**  Categorize your daily tasks based on urgency and importance. Focus on the "Important, Not Urgent" tasks – these are often the most impactful for long-term goals.
# *   **Time Blocking:** Schedule specific blocks of time in your day for working on your goals. Treat these blocks as appointments you can't miss.
# *   **Eat the Frog:** Do the most challenging or unpleasant task first thing in the morning. This removes the mental burden and allows you to tackle the rest of your day with more energy.
# *   **Batching:** Group similar tasks together to minimize context switching and increase efficiency. For example, dedicate one block of time to all your writing tasks or another to all your email correspondence.
#
# **5. Tracking, Review, and Adjustment**
#
# *   **Progress Tracking:** Use a journal, spreadsheet, or app to track your progress on a daily or weekly basis.
# *   **Weekly Review:** At the end of each week, review your accomplishments, identify any roadblocks, and adjust your plan as needed. Be honest with yourself.
# *   **Monthly Review:**  Conduct a more in-depth review at the end of each month. Are you on track to meet your quarterly goals?  Do you need to make any significant changes to your strategy?
# *   **Be Flexible:** Life happens. Don't be afraid to adjust your goals or timeline if necessary. The key is to stay adaptable and keep moving forward.
#
# **6. Overcoming Procrastination (Actionable Tips)**
#
# *   **The 2-Minute Rule:** If a task takes less than 2 minutes, do it immediately. This prevents small tasks from piling up and becoming overwhelming.
# *   **Break it Down Further:** If a task still feels too daunting, break it down into even smaller, more manageable steps.  Sometimes, the hardest part is just getting started.
# *   **Pomodoro Technique:** Work in focused bursts of 25 minutes, followed by a 5-minute break. This can help you stay focused and avoid burnout.
# *   **Remove Distractions:** Identify your biggest distractions (e.g., social media, email) and eliminate them during your focused work periods. Use website blockers or turn off notifications.
# *   **Find an Accountability Partner:**  Share your goals with a friend, family member, or colleague and ask them to check in on your progress.
# *   **Reward Yourself:**  Celebrate your accomplishments, no matter how small. This will help you stay motivated and build momentum.  Make sure the reward aligns with your goals (e.g., don't reward finishing a workout with junk food).
# *   **Practice Self-Compassion:**  Don't beat yourself up if you slip up.  Everyone procrastinates occasionally.  Acknowledge it, learn from it, and get back on track.
# *   **Focus on Progress, Not Perfection:** Perfectionism is a major cause of procrastination.  Don't wait until everything is "perfect" to start. Just get started and refine as you go.
# *   **Identify Underlying Fears:** Sometimes, procrastination is a symptom of a deeper fear of failure, success, or being judged. If you suspect this is the case, consider exploring these fears with a therapist or coach.
#
# **In summary:**  Setting achievable goals is a process of self-discovery, careful planning, consistent action, and ongoing evaluation.  By using the SMART framework, breaking down your goals into smaller steps, prioritizing your time, and overcoming procrastination, you can significantly increase your chances of success. Good luck!
#
# --------------------------------------------------
# Question: What’s a good morning mindfulness routine?
# Answer:
# Okay, let's work together to set some achievable goals for the next 6 months. Here's a breakdown of a process incorporating mindfulness and balance:
#
# **1. Mindful Reflection (Before you even set goals!)**
#
# *   **Quiet the Noise:** Find a quiet space where you won't be disturbed. Take 5-10 minutes to just breathe. Focus on your breath entering and leaving your body.  This helps to clear your mind and become more present.
# *   **Connect with Values:** Ask yourself: What truly matters to me? What are my core values? (e.g., creativity, connection, health, learning, contribution). Jot down a few key values. These will be your compass.
# *   **Acknowledge Current State:**  Without judgment, consider where you are right now in different areas of your life (career, relationships, health, personal growth, finances).  What's working well? What feels stagnant or needs attention?
#
# **2. Brainstorming & Prioritization (SMART Goals with a mindful twist!)**
#
# *   **Generate Ideas:**  Based on your values and your current state, brainstorm a list of things you'd *like* to achieve in the next 6 months. Don't censor yourself at this stage. Just let the ideas flow. Think about big picture and smaller, supporting tasks.
# *   **SMART-ify Your Goals:** Now, let's apply the SMART framework, but with a mindful lens:
#     *   **Specific:** Instead of "Get healthier," try "Walk for 30 minutes, 3 times a week."
#     *   **Measurable:**  How will you know you've achieved it? "Write 500 words per week for my book."
#     *   **Achievable:** Be realistic.  Consider your current commitments and resources. Avoid setting yourself up for failure. Think realistically about the time you have available.
#     *   **Relevant:**  Does this goal align with your values? Will it truly contribute to your overall well-being and happiness?
#     *   **Time-bound:**  Set a deadline. "Complete online course by [Date]."
# *   **Prioritize Ruthlessly:**  Look at your SMART goals. You likely have too many. Select *no more than 3-5* key goals to focus on for the next 6 months. Less is more.  Choose the ones that will have the biggest positive impact on your life and align most strongly with your values. Ask yourself: "Which of these, if achieved, would make the biggest difference to my overall well-being?"
#
# **3. Break it Down & Create a Plan**
#
# *   **Chunking:**  Take each of your chosen goals and break them down into smaller, more manageable steps. What are the specific actions you need to take each week or month to move closer to your goal?
# *   **Time Blocking:** Schedule specific times in your calendar to work on these actions. Treat these appointments as sacred. This increases the likelihood of follow-through.
# *   **Mindful Scheduling:**  Don't pack your schedule so tightly that you feel stressed.  Build in buffer time, rest, and activities you enjoy.  Remember the importance of balance.
#
# **4. Cultivate Mindfulness and Self-Compassion**
#
# *   **Regular Check-ins:** Schedule a weekly or bi-weekly review. How are you progressing? Are you on track? Do you need to adjust your plan? Be honest with yourself.
# *   **Acknowledge Progress:** Celebrate small wins along the way. This helps to maintain motivation.
# *   **Practice Self-Compassion:**  Inevitably, you'll encounter obstacles and setbacks. Don't beat yourself up. Treat yourself with kindness and understanding. Ask yourself, "What would I say to a friend in this situation?"
# *   **Stay Present:**  Don't get too caught up in the future. Focus on taking action in the present moment.  Each small step contributes to the larger goal.
#
# **Example:**
#
# Let's say one of your values is "Health" and you identified "Get healthier" as an area needing attention.
#
# *   **SMART Goal:** "Walk for 30 minutes, 3 times per week, to improve cardiovascular health and reduce stress."
# *   **Breakdown:**
#     *   **Week 1:** Identify 3 days and times to walk.  Find a walking route you enjoy.
#     *   **Week 2:** Purchase comfortable walking shoes if needed.
#     *   **Ongoing:** Walk for 30 minutes on scheduled days.
# *   **Mindful Check-in:** Each Sunday, review your walking schedule for the upcoming week and make any necessary adjustments.
#
# By incorporating mindfulness into the goal-setting process, you can create goals that are not only achievable but also aligned with your values and contribute to your overall well-being. Remember, it's a journey, not a race. Be patient, kind to yourself, and enjoy the process.
#
# --------------------------------------------------
